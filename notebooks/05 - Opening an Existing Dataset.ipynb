# %% [markdown]
# # Now you have your data ready to work with. You can now access this Dataset anytime without having to do any of the processing steps that were just completed.
#
# # Simply instantiate the Dataset by passing the `data_path` keyword argument, and it will detect the processed files.

# %%
import trackio as tio

# %%
#define the data_path
data_path = 'example0'

#read the processed Dataset
ds = tio.read(data_path=data_path)

ds
# Out:
# Type:
#     <class 'trackio.Dataset.Dataset'>
# Status:
#     0 Unprocessed CSV Files
#     0 Processed CSV Files
#     0 Unsplit Agent Files
#     172 Split Agent Files
# Static Data Fields:
#     ['AISCode', 'Agent ID', 'Length', 'MMSI', 'Name', 'Width']
# Dynamic Data Fields:
#     ['Coursing', 'Draft', 'Speed', 'Status', 'Time', 'X', 'Y']
# Metadata:
#     X: degrees
#     Y: degrees
#     CRS: EPSG:4326
# Data Path:
#     c:\code\trackio\notebooks\example0

# %% [markdown]
# # Notice how the split agent (track) files are detected, along with the metadata, agent, and track databases

# %%
ds.agents.head(5)
# Out:
#                        MMSI                Name AISCode Length Width npoints  \
# Agent ID
# Vessel_368111610  368111610                 NaN     NaN    NaN   NaN      35
# Vessel_369230000  369230000        PHILADELPHIA    31.0    NaN   NaN      94
# Vessel_366952790  366952790      GUY V MOLINARI    60.0   94.0  21.0     591
# Vessel_367000140  367000140   SAMUEL I NEWHOUSE    60.0   94.0  21.0    1286
# Vessel_367165430  367165430  BRUCE A MCALLISTER    31.0   32.0   9.0     117
#
#                  ntracks      Xmin      Xmax      Ymin      Ymax  \
# Agent ID
# Vessel_368111610       1 -74.07277 -74.01703  40.62842  40.71297
# Vessel_369230000       1 -74.12809 -73.95479  40.64258  40.76004
# Vessel_366952790       1  -74.0718 -74.01311  40.64367  40.70042
# Vessel_367000140       1  -74.0724 -74.01324  40.64356  40.70044
# Vessel_367165430       1 -74.12708 -74.09072  40.64282  40.65088
#
#                           Start Time            End Time  \
# Agent ID
# ...

# %%
ds.tracks.head(5)
# Out:
#                           MMSI                Name  AISCode  Length  Width  \
# Track ID
# Vessel_368111610_T0  368111610                 NaN      NaN     NaN    NaN
# Vessel_369230000_T0  369230000        PHILADELPHIA     31.0     NaN    NaN
# Vessel_366952790_T0  366952790      GUY V MOLINARI     60.0    94.0   21.0
# Vessel_367000140_T0  367000140   SAMUEL I NEWHOUSE     60.0    94.0   21.0
# Vessel_367165430_T0  367165430  BRUCE A MCALLISTER     31.0    32.0    9.0
#
#                              Agent ID  npoints      Xmin      Xmax      Ymin  \
# Track ID
# Vessel_368111610_T0  Vessel_368111610       35 -74.07277 -74.01703  40.62842
# Vessel_369230000_T0  Vessel_369230000       94 -74.12809 -73.95479  40.64258
# Vessel_366952790_T0  Vessel_366952790      591 -74.07180 -74.01311  40.64367
# Vessel_367000140_T0  Vessel_367000140     1286 -74.07240 -74.01324  40.64356
# Vessel_367165430_T0  Vessel_367165430      117 -74.12708 -74.09072  40.64282
#
# ...

# %% [markdown]
# # You can also subset the original Dataset by simply passing a list of track files with the `data_files` keyword argument.
#
# # WILL ADD AFTER FIXING OUTPATH SHIT
