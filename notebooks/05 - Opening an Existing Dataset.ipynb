# %% [markdown]
# # Now you have your data ready to work with. You can now access this Dataset anytime without having to do any of the processing steps that were just completed.
#
# # Simply instantiate the Dataset by passing the `data_path` keyword argument, and it will detect the processed files.

# %%
import trackio as tio

# %%
#define the data_path
data_path = 'example0'

#read the processed Dataset
ds = tio.read(data_path=data_path)

ds
# Out:
# Type:
#     <class 'trackio.Dataset.Dataset'>
# Status:
#     0 Unprocessed CSV Files
#     0 Processed CSV Files
#     0 Unsplit Agent Files
#     172 Split Agent Files
# Static Data Fields:
#     ['AISCode', 'Agent ID', 'Length', 'MMSI', 'Name', 'Width']
# Dynamic Data Fields:
#     ['Coursing', 'Draft', 'Speed', 'Status', 'Time', 'X', 'Y']
# Metadata:
#     X: degrees
#     Y: degrees
#     CRS: EPSG:4326
# Data Path:
#     c:\code\trackio\notebooks\example0

# %% [markdown]
# # Notice how the split agent (track) files are detected, along with the metadata, agent, and track databases

# %%
ds.agents.head(5)
# Out:
#                        MMSI                  Name AISCode Length Width  \
# Agent ID
# Vessel_367459570  367459570           CORAL COAST    31.0   34.0   9.0
# Vessel_367770270  367770270  CAPT BRIAN A MCALLIS    31.0    NaN   NaN
# Vessel_367586480  367586480       MANHATTAN ELITE    60.0   25.0   6.0
# Vessel_367790830  367790830             OWLS HEAD    60.0    NaN   NaN
# Vessel_367796040  367796040               SEA FOX    31.0   22.0   7.0
#
#                  npoints ntracks      Xmin      Xmax      Ymin      Ymax  \
# Agent ID
# Vessel_367459570      59       1 -74.02483  -73.9545    40.698   40.7605
# Vessel_367770270     359       1 -74.12577 -74.05318   40.6198  40.65129
# Vessel_367586480    1244       1 -74.01035 -74.01013  40.74731  40.74757
# Vessel_367790830     523       1 -74.00614 -73.94803  40.70187  40.76106
# Vessel_367796040    1134       1 -74.07762 -73.95417  40.66082  40.76055
#
#                           Start Time            End Time  \
# Agent ID
# Vessel_367459570 2021-01-01 10:13:36 2021-01-01 11:19:46
# Vessel_367770270 2021-01-01 00:17:13 2021-01-01 18:15:24
# Vessel_367586480 2021-01-01 00:17:20 2021-01-01 23:59:59
# Vessel_367790830 2021-01-01 00:17:18 2021-01-01 23:43:13
# Vessel_367796040 2021-01-01 00:17:16 2021-01-01 23:59:56
#
#                                                                File  \
# Agent ID
# Vessel_367459570  c:\code\trackio\notebooks\example0\Vessel_3674...
# Vessel_367770270  c:\code\trackio\notebooks\example0\Vessel_3677...
# Vessel_367586480  c:\code\trackio\notebooks\example0\Vessel_3675...
# Vessel_367790830  c:\code\trackio\notebooks\example0\Vessel_3677...
# Vessel_367796040  c:\code\trackio\notebooks\example0\Vessel_3677...
#
#                                                            geometry
# Agent ID
# Vessel_367459570  POLYGON ((-73.95450 40.69800, -73.95450 40.760...
# Vessel_367770270  POLYGON ((-74.05318 40.61980, -74.05318 40.651...
# Vessel_367586480  POLYGON ((-74.01013 40.74731, -74.01013 40.747...
# Vessel_367790830  POLYGON ((-73.94803 40.70187, -73.94803 40.761...
# Vessel_367796040  POLYGON ((-73.95417 40.66082, -73.95417 40.760...

# %%
ds.tracks.head(5)
# Out:
#                           MMSI                  Name  AISCode  Length  Width  \
# Track ID
# Vessel_367459570_T0  367459570           CORAL COAST     31.0    34.0    9.0
# Vessel_367770270_T0  367770270  CAPT BRIAN A MCALLIS     31.0     NaN    NaN
# Vessel_367586480_T0  367586480       MANHATTAN ELITE     60.0    25.0    6.0
# Vessel_367790830_T0  367790830             OWLS HEAD     60.0     NaN    NaN
# Vessel_367796040_T0  367796040               SEA FOX     31.0    22.0    7.0
#
#                              Agent ID  npoints      Xmin      Xmax      Ymin  \
# Track ID
# Vessel_367459570_T0  Vessel_367459570       59 -74.02483 -73.95450  40.69800
# Vessel_367770270_T0  Vessel_367770270      359 -74.12577 -74.05318  40.61980
# Vessel_367586480_T0  Vessel_367586480     1244 -74.01035 -74.01013  40.74731
# Vessel_367790830_T0  Vessel_367790830      523 -74.00614 -73.94803  40.70187
# Vessel_367796040_T0  Vessel_367796040     1134 -74.07762 -73.95417  40.66082
#
#                      ...      Xend      Yend Effective Distance  \
# Track ID             ...
# Vessel_367459570_T0  ... -74.00950  40.76033           0.055000
# Vessel_367770270_T0  ... -74.12577  40.64352           0.020812
# Vessel_367586480_T0  ... -74.01022  40.74741           0.000072
# Vessel_367790830_T0  ... -73.95647  40.75805           0.060905
# Vessel_367796040_T0  ... -74.07756  40.68622           0.000030
#
#                     Min Temporal Resolution  Mean Temporal Resolution  \
# Track ID
# Vessel_367459570_T0                      50                 68.448276
# Vessel_367770270_T0                       9                180.701117
# Vessel_367586480_T0                       9                 68.671762
# Vessel_367790830_T0                       6                161.599617
# Vessel_367796040_T0                      10                 75.339806
#
#                      Max Temporal Resolution  Min Spatial Resolution  \
# Track ID
# Vessel_367459570_T0                       72                0.001897
# Vessel_367770270_T0                    40923                0.000000
# Vessel_367586480_T0                       82                0.000000
# Vessel_367790830_T0                    44332                0.000000
# Vessel_367796040_T0                     7989                0.000000
#
#                      Mean Spatial Resolution  Max Spatial Resolution  \
# Track ID
# Vessel_367459570_T0                 0.002979                0.003862
# Vessel_367770270_T0                 0.000705                0.004033
# Vessel_367586480_T0                 0.000030                0.000125
# Vessel_367790830_T0                 0.002436                0.009810
# Vessel_367796040_T0                 0.000360                0.004348
#
#                                                               geometry
# Track ID
# Vessel_367459570_T0  POLYGON ((-73.95450 40.69800, -73.95450 40.760...
# Vessel_367770270_T0  POLYGON ((-74.05318 40.61980, -74.05318 40.651...
# Vessel_367586480_T0  POLYGON ((-74.01013 40.74731, -74.01013 40.747...
# Vessel_367790830_T0  POLYGON ((-73.94803 40.70187, -73.94803 40.761...
# Vessel_367796040_T0  POLYGON ((-73.95417 40.66082, -73.95417 40.760...
#
# [5 rows x 30 columns]

# %% [markdown]
# # You can also subset the original Dataset by simply passing a list of track files with the `data_files` keyword argument.
#
# # WILL ADD AFTER FIXING OUTPATH SHIT
