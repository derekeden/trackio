# %% [markdown]
# # Now you have your data ready to work with. You can now access this `Dataset` anytime without having to do any of the processing steps that were just completed.
#
# # Simply instantiate the `Dataset` by passing the `data_path` keyword argument, and it will detect the processed files.
# ___

# %%
import trackio as tio

# %%
#define the data_path
data_path = './example0'

#read the processed Dataset
ds = tio.read(data_path=data_path)

ds
# Out:
# Type:
#     <class 'trackio.Dataset.Dataset'>
# Status:
#     0 Unprocessed CSV Files
#     0 Processed CSV Files
#     0 Unsplit Agent Files
#     172 Split Agent Files
# Static Data Fields:
#     ['AISCode', 'Agent ID', 'Length', 'MMSI', 'Name', 'Width']
# Dynamic Data Fields:
#     ['Coursing', 'Draft', 'Speed', 'Status', 'Time', 'X', 'Y']
# Metadata:
#     X: degrees
#     Y: degrees
#     CRS: EPSG:4326
# Data Path:
#     c:\code\trackio\notebooks\example0

# %% [markdown]
# ___
# ## Notice how the split agent (track) files are detected, along with the metadata, agent, and track databases

# %%
ds.agents.head(5)
# Out:
#                        MMSI                Name AISCode Length Width npoints  \
# Agent ID
# Vessel_367586480  367586480     MANHATTAN ELITE    60.0   25.0   6.0    1244
# Vessel_636013689  636013689           YM UBERTY    70.0  333.0  42.0      51
# Vessel_367008110  367008110          NEW JERSEY    90.0   44.0   8.0     464
# Vessel_367165430  367165430  BRUCE A MCALLISTER    31.0   32.0   9.0     117
# Vessel_338380535  338380535             WING IT    36.0   16.0   5.0     401
#
#                  ntracks      Xmin      Xmax      Ymin      Ymax  \
# Agent ID
# Vessel_367586480       1 -74.01035 -74.01013  40.74731  40.74757
# Vessel_636013689       1 -74.12593 -74.03177  40.57152  40.65135
# Vessel_367008110       1 -74.06484 -74.06443  40.61763  40.61801
# Vessel_367165430       1 -74.12708 -74.09072  40.64282  40.65088
# Vessel_338380535       1 -74.04486 -74.04475   40.7108  40.71095
#
#                           Start Time            End Time  \
# Agent ID
# Vessel_367586480 2021-01-01 00:17:20 2021-01-01 23:59:59
# Vessel_636013689 2021-01-01 14:15:52 2021-01-01 15:14:01
# Vessel_367008110 2021-01-01 00:21:32 2021-01-01 23:57:41
# Vessel_367165430 2021-01-01 20:34:41 2021-01-01 23:45:08
# Vessel_338380535 2021-01-01 00:18:44 2021-01-01 23:54:45
#
#                                                                File  \
# Agent ID
# Vessel_367586480  c:\code\trackio\notebooks\example0\Vessel_3675...
# Vessel_636013689  c:\code\trackio\notebooks\example0\Vessel_6360...
# Vessel_367008110  c:\code\trackio\notebooks\example0\Vessel_3670...
# Vessel_367165430  c:\code\trackio\notebooks\example0\Vessel_3671...
# Vessel_338380535  c:\code\trackio\notebooks\example0\Vessel_3383...
#
#                                                            geometry
# Agent ID
# Vessel_367586480  POLYGON ((-74.01013 40.74731, -74.01013 40.747...
# Vessel_636013689  POLYGON ((-74.03177 40.57152, -74.03177 40.651...
# Vessel_367008110  POLYGON ((-74.06443 40.61763, -74.06443 40.618...
# Vessel_367165430  POLYGON ((-74.09072 40.64282, -74.09072 40.650...
# Vessel_338380535  POLYGON ((-74.04475 40.71080, -74.04475 40.710...

# %%
ds.tracks.head(5)
# Out:
#                           MMSI                Name  AISCode  Length  Width  \
# Track ID
# Vessel_367586480_T0  367586480     MANHATTAN ELITE     60.0    25.0    6.0
# Vessel_636013689_T0  636013689           YM UBERTY     70.0   333.0   42.0
# Vessel_367008110_T0  367008110          NEW JERSEY     90.0    44.0    8.0
# Vessel_367165430_T0  367165430  BRUCE A MCALLISTER     31.0    32.0    9.0
# Vessel_338380535_T0  338380535             WING IT     36.0    16.0    5.0
#
#                              Agent ID  npoints      Xmin      Xmax      Ymin  \
# Track ID
# Vessel_367586480_T0  Vessel_367586480     1244 -74.01035 -74.01013  40.74731
# Vessel_636013689_T0  Vessel_636013689       51 -74.12593 -74.03177  40.57152
# Vessel_367008110_T0  Vessel_367008110      464 -74.06484 -74.06443  40.61763
# Vessel_367165430_T0  Vessel_367165430      117 -74.12708 -74.09072  40.64282
# Vessel_338380535_T0  Vessel_338380535      401 -74.04486 -74.04475  40.71080
#
#                      ...      Yend Effective Distance Min Temporal Resolution  \
# Track ID             ...
# Vessel_367586480_T0  ...  40.74741           0.000072                       9
# Vessel_636013689_T0  ...  40.64317           0.118321                      61
# Vessel_367008110_T0  ...  40.61784           0.000040                     170
# Vessel_367165430_T0  ...  40.64395           0.003159                      10
# Vessel_338380535_T0  ...  40.71090           0.000030                     176
#
#                     Mean Temporal Resolution  Max Temporal Resolution  \
# Track ID
# Vessel_367586480_T0                68.671762                       82
# Vessel_636013689_T0                69.780000                       72
# Vessel_367008110_T0               183.518359                      363
# Vessel_367165430_T0                98.508621                      186
# Vessel_338380535_T0               212.402500                      543
#
#                      Min Spatial Resolution  Mean Spatial Resolution  \
# Track ID
# Vessel_367586480_T0                0.000000                 0.000030
# Vessel_636013689_T0                0.002416                 0.002983
# Vessel_367008110_T0                0.000000                 0.000042
# Vessel_367165430_T0                0.000000                 0.000672
# Vessel_338380535_T0                0.000000                 0.000021
#
#                      Max Spatial Resolution   Sinuosity  \
# Track ID
# Vessel_367586480_T0                0.000125  519.095409
# Vessel_636013689_T0                0.004303    1.260569
# Vessel_367008110_T0                0.000278  489.153349
# Vessel_367165430_T0                0.005034   24.691208
# Vessel_338380535_T0                0.000100  276.920303
#
#                                                               geometry
# Track ID
# Vessel_367586480_T0  POLYGON ((-74.01013 40.74731, -74.01013 40.747...
# Vessel_636013689_T0  POLYGON ((-74.03177 40.57152, -74.03177 40.651...
# Vessel_367008110_T0  POLYGON ((-74.06443 40.61763, -74.06443 40.618...
# Vessel_367165430_T0  POLYGON ((-74.09072 40.64282, -74.09072 40.650...
# Vessel_338380535_T0  POLYGON ((-74.04475 40.71080, -74.04475 40.710...
#
# [5 rows x 31 columns]

# %% [markdown]
# ___
# ## TODO You can also subset the original Dataset by simply passing a list of track files with the `data_files` keyword argument.
# ___
