# %% [markdown]
# # Now you have your data ready to work with. You can now access this `Dataset` anytime without having to do any of the processing steps that were just completed.
#
# # Simply instantiate the `Dataset` by passing the `data_path` keyword argument, and it will detect the processed files.
# ___

# %%
import trackio as tio

# %%
#define the data_path
data_path = './example0'

#read the processed Dataset
ds = tio.read(data_path=data_path)

ds
# Out:
# Type:
#     <class 'trackio.Dataset.Dataset'>
# Status:
#     0 Unprocessed CSV Files
#     0 Processed CSV Files
#     0 Unsplit Agent Files
#     172 Split Agent Files
# Static Data Fields:
#     ['AISCode', 'Agent ID', 'Length', 'MMSI', 'Name', 'Width']
# Dynamic Data Fields:
#     ['Coursing', 'Draft', 'Speed', 'Status', 'Time', 'X', 'Y']
# Metadata:
#     X: degrees
#     Y: degrees
#     CRS: EPSG:4326
# Data Path:
#     c:\code\trackio\notebooks\example0

# %% [markdown]
# ___
# ## Notice how the split agent (track) files are detected, along with the metadata, agent, and track databases

# %%
ds.agents.head(5)
# Out:
#                        MMSI         Name AISCode Length Width npoints ntracks  \
# Agent ID
# Vessel_366939790  366939790  DORIS MORAN    31.0   38.0  10.0      16       1
# Vessel_367597530  367597530  HUNTS POINT    90.0   88.0  21.0    1245       1
# Vessel_367789230  367789230     NAVASANA    37.0   11.0   NaN     393       1
# Vessel_367796050  367796050     SEA LION    31.0   19.0   6.0    1242       1
# Vessel_369389000  369389000          NaN     NaN    NaN   NaN     112       1
#
#                       Xmin      Xmax      Ymin      Ymax          Start Time  \
# Agent ID
# Vessel_366939790 -74.12746 -74.11722  40.64204  40.64495 2021-01-01 20:07:33
# Vessel_367597530 -73.96945 -73.96941  40.70167  40.70171 2021-01-01 00:17:21
# Vessel_367789230 -74.04179 -74.04161  40.71145  40.71177 2021-01-01 00:19:45
# Vessel_367796050 -74.07765 -74.07759  40.68621  40.68627 2021-01-01 00:17:17
# Vessel_369389000  -74.1262 -73.95374  40.64228  40.76103 2021-01-01 11:36:06
#
#                             End Time  \
# Agent ID
# Vessel_366939790 2021-01-01 20:24:01
# Vessel_367597530 2021-01-01 23:59:01
# Vessel_367789230 2021-01-01 23:58:44
# Vessel_367796050 2021-01-01 23:59:07
# Vessel_369389000 2021-01-01 13:38:44
#
#                                                                File  \
# Agent ID
# Vessel_366939790  c:\code\trackio\notebooks\example0\Vessel_3669...
# Vessel_367597530  c:\code\trackio\notebooks\example0\Vessel_3675...
# Vessel_367789230  c:\code\trackio\notebooks\example0\Vessel_3677...
# Vessel_367796050  c:\code\trackio\notebooks\example0\Vessel_3677...
# Vessel_369389000  c:\code\trackio\notebooks\example0\Vessel_3693...
#
#                                                            geometry
# Agent ID
# Vessel_366939790  POLYGON ((-74.11722 40.64204, -74.11722 40.644...
# Vessel_367597530  POLYGON ((-73.96941 40.70167, -73.96941 40.701...
# Vessel_367789230  POLYGON ((-74.04161 40.71145, -74.04161 40.711...
# Vessel_367796050  POLYGON ((-74.07759 40.68621, -74.07759 40.686...
# Vessel_369389000  POLYGON ((-73.95374 40.64228, -73.95374 40.761...

# %%
ds.tracks.head(5)
# Out:
#                           MMSI         Name  AISCode  Length  Width  \
# Track ID
# Vessel_366939790_T0  366939790  DORIS MORAN     31.0    38.0   10.0
# Vessel_367597530_T0  367597530  HUNTS POINT     90.0    88.0   21.0
# Vessel_367789230_T0  367789230     NAVASANA     37.0    11.0    NaN
# Vessel_367796050_T0  367796050     SEA LION     31.0    19.0    6.0
# Vessel_369389000_T0  369389000          NaN      NaN     NaN    NaN
#
#                              Agent ID  npoints      Xmin      Xmax      Ymin  \
# Track ID
# Vessel_366939790_T0  Vessel_366939790       16 -74.12746 -74.11722  40.64204
# Vessel_367597530_T0  Vessel_367597530     1245 -73.96945 -73.96941  40.70167
# Vessel_367789230_T0  Vessel_367789230      393 -74.04179 -74.04161  40.71145
# Vessel_367796050_T0  Vessel_367796050     1242 -74.07765 -74.07759  40.68621
# Vessel_369389000_T0  Vessel_369389000      112 -74.12620 -73.95374  40.64228
#
#                      ...      Yend Effective Distance Min Temporal Resolution  \
# Track ID             ...
# Vessel_366939790_T0  ...  40.64355           0.001923                      61
# Vessel_367597530_T0  ...  40.70170           0.000000                       9
# Vessel_367789230_T0  ...  40.71154           0.000010                     176
# Vessel_367796050_T0  ...  40.68625           0.000028                       9
# Vessel_369389000_T0  ...  40.76103           0.209390                      16
#
#                     Mean Temporal Resolution  Max Temporal Resolution  \
# Track ID
# Vessel_366939790_T0                65.866667                       72
# Vessel_367597530_T0                68.569132                       81
# Vessel_367789230_T0               217.191327                      720
# Vessel_367796050_T0                68.742949                       81
# Vessel_369389000_T0                66.288288                      109
#
#                      Min Spatial Resolution  Mean Spatial Resolution  \
# Track ID
# Vessel_366939790_T0                 0.00062                 0.001321
# Vessel_367597530_T0                 0.00000                 0.000002
# Vessel_367789230_T0                 0.00000                 0.000032
# Vessel_367796050_T0                 0.00000                 0.000012
# Vessel_369389000_T0                 0.00000                 0.002208
#
#                      Max Spatial Resolution    Sinuosity  \
# Track ID
# Vessel_366939790_T0                0.003737    10.306245
# Vessel_367597530_T0                0.000022          inf
# Vessel_367789230_T0                0.000300  1263.619830
# Vessel_367796050_T0                0.000045   511.504964
# Vessel_369389000_T0                0.008266     1.170297
#
#                                                               geometry
# Track ID
# Vessel_366939790_T0  POLYGON ((-74.11722 40.64204, -74.11722 40.644...
# Vessel_367597530_T0  POLYGON ((-73.96941 40.70167, -73.96941 40.701...
# Vessel_367789230_T0  POLYGON ((-74.04161 40.71145, -74.04161 40.711...
# Vessel_367796050_T0  POLYGON ((-74.07759 40.68621, -74.07759 40.686...
# Vessel_369389000_T0  POLYGON ((-73.95374 40.64228, -73.95374 40.761...
#
# [5 rows x 31 columns]

# %% [markdown]
# ___
# ## ***TODO*** You can also subset the original Dataset by simply passing a list of track files with the `data_files` keyword argument.
# ___
