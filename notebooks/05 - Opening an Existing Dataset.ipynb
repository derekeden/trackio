# %% [markdown]
# # Now you have your data ready to work with. You can now access this `Dataset` anytime without having to do any of the processing steps that were just completed.
#
# # Simply instantiate the `Dataset` by passing the `data_path` keyword argument, and it will detect the processed files.
# ___

# %%
import trackio as tio

# %%
#define the data_path
data_path = './example0'

#read the processed Dataset
ds = tio.read(data_path=data_path)

ds
# Out:
# Type:
#     <class 'trackio.Dataset.Dataset'>
# Status:
#     0 Unprocessed CSV Files
#     0 Processed CSV Files
#     0 Unsplit Agent Files
#     172 Split Agent Files
# Static Data Fields:
#     ['AISCode', 'Agent ID', 'Length', 'MMSI', 'Name', 'Width']
# Dynamic Data Fields:
#     ['Coursing', 'Draft', 'Speed', 'Status', 'Time', 'X', 'Y']
# Metadata:
#     X: degrees
#     Y: degrees
#     CRS: EPSG:4326
# Data Path:
#     c:\code\trackio\notebooks\example0

# %% [markdown]
# ___
# ## Notice how the split agent (track) files are detected, along with the metadata, agent, and track databases

# %%
ds.agents.head(5)
# Out:
#                        MMSI       Name AISCode Length Width npoints ntracks  \
# Agent ID
# Vessel_338380535  338380535    WING IT    36.0   16.0   5.0     401       1
# Vessel_636019179  636019179        NaN     NaN    NaN   NaN     423       1
# Vessel_366999974  366999974    CG LINE    90.0   19.0   5.0     394       1
# Vessel_367638180  367638180     NYPD 4    90.0    NaN   NaN     878       1
# Vessel_367419080  367419080  ELK RIVER    31.0   28.0   9.0     107       1
#
#                       Xmin      Xmax      Ymin      Ymax          Start Time  \
# Agent ID
# Vessel_338380535 -74.04486 -74.04475   40.7108  40.71095 2021-01-01 00:18:44
# Vessel_636019179 -74.11067 -74.03106  40.57143  40.65172 2021-01-01 06:37:21
# Vessel_366999974 -74.09025  -74.0902  40.67271  40.67276 2021-01-01 00:25:21
# Vessel_367638180 -74.04452 -73.99036  40.60818  40.71348 2021-01-01 00:42:18
# Vessel_367419080 -74.12767 -74.11798  40.68735  40.70743 2021-01-01 04:57:06
#
#                             End Time  \
# Agent ID
# Vessel_338380535 2021-01-01 23:54:45
# Vessel_636019179 2021-01-01 23:57:14
# Vessel_366999974 2021-01-01 23:58:03
# Vessel_367638180 2021-01-01 17:57:54
# Vessel_367419080 2021-01-01 13:31:26
#
#                                                                File  \
# Agent ID
# Vessel_338380535  c:\code\trackio\notebooks\example0\Vessel_3383...
# Vessel_636019179  c:\code\trackio\notebooks\example0\Vessel_6360...
# Vessel_366999974  c:\code\trackio\notebooks\example0\Vessel_3669...
# Vessel_367638180  c:\code\trackio\notebooks\example0\Vessel_3676...
# Vessel_367419080  c:\code\trackio\notebooks\example0\Vessel_3674...
#
#                                                            geometry
# Agent ID
# Vessel_338380535  POLYGON ((-74.04475 40.71080, -74.04475 40.710...
# Vessel_636019179  POLYGON ((-74.03106 40.57143, -74.03106 40.651...
# Vessel_366999974  POLYGON ((-74.09020 40.67271, -74.09020 40.672...
# Vessel_367638180  POLYGON ((-73.99036 40.60818, -73.99036 40.713...
# Vessel_367419080  POLYGON ((-74.11798 40.68735, -74.11798 40.707...

# %%
ds.tracks.head(5)
# Out:
#                           MMSI       Name  AISCode  Length  Width  \
# Track ID
# Vessel_338380535_T0  338380535    WING IT     36.0    16.0    5.0
# Vessel_636019179_T0  636019179        NaN      NaN     NaN    NaN
# Vessel_366999974_T0  366999974    CG LINE     90.0    19.0    5.0
# Vessel_367638180_T0  367638180     NYPD 4     90.0     NaN    NaN
# Vessel_367419080_T0  367419080  ELK RIVER     31.0    28.0    9.0
#
#                              Agent ID  npoints      Xmin      Xmax      Ymin  \
# Track ID
# Vessel_338380535_T0  Vessel_338380535      401 -74.04486 -74.04475  40.71080
# Vessel_636019179_T0  Vessel_636019179      423 -74.11067 -74.03106  40.57143
# Vessel_366999974_T0  Vessel_366999974      394 -74.09025 -74.09020  40.67271
# Vessel_367638180_T0  Vessel_367638180      878 -74.04452 -73.99036  40.60818
# Vessel_367419080_T0  Vessel_367419080      107 -74.12767 -74.11798  40.68735
#
#                      ...      Yend Effective Distance Min Temporal Resolution  \
# Track ID             ...
# Vessel_338380535_T0  ...  40.71090           0.000030                     176
# Vessel_636019179_T0  ...  40.64858           0.102359                      30
# Vessel_366999974_T0  ...  40.67275           0.000010                     124
# Vessel_367638180_T0  ...  40.69707           0.059229                      10
# Vessel_367419080_T0  ...  40.68786           0.000874                      38
#
#                     Mean Temporal Resolution  Max Temporal Resolution  \
# Track ID
# Vessel_338380535_T0               212.402500                      543
# Vessel_636019179_T0               147.850711                      538
# Vessel_366999974_T0               215.679389                      721
# Vessel_367638180_T0                70.850627                      138
# Vessel_367419080_T0               291.132075                    23850
#
#                      Min Spatial Resolution  Mean Spatial Resolution  \
# Track ID
# Vessel_338380535_T0                     0.0                 0.000021
# Vessel_636019179_T0                     0.0                 0.000386
# Vessel_366999974_T0                     0.0                 0.000003
# Vessel_367638180_T0                     0.0                 0.000519
# Vessel_367419080_T0                     0.0                 0.000882
#
#                      Max Spatial Resolution   Sinuosity  \
# Track ID
# Vessel_338380535_T0                0.000100  276.920303
# Vessel_636019179_T0                0.003041    1.592159
# Vessel_366999974_T0                0.000042  113.041631
# Vessel_367638180_T0                0.012578    7.690828
# Vessel_367419080_T0                0.003248  106.964027
#
#                                                               geometry
# Track ID
# Vessel_338380535_T0  POLYGON ((-74.04475 40.71080, -74.04475 40.710...
# Vessel_636019179_T0  POLYGON ((-74.03106 40.57143, -74.03106 40.651...
# Vessel_366999974_T0  POLYGON ((-74.09020 40.67271, -74.09020 40.672...
# Vessel_367638180_T0  POLYGON ((-73.99036 40.60818, -73.99036 40.713...
# Vessel_367419080_T0  POLYGON ((-74.11798 40.68735, -74.11798 40.707...
#
# [5 rows x 31 columns]

# %% [markdown]
# ___
# ## ***TODO*** You can also subset the original Dataset by simply passing a list of track files with the `data_files` keyword argument.
# ___
