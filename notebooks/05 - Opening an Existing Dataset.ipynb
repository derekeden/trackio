# %% [markdown]
# # Now you have your data ready to work with. You can now access this `Dataset` anytime without having to do any of the processing steps that were just completed.
#
# # Simply instantiate the `Dataset` by passing the `data_path` keyword argument, and it will detect the processed files.
# ___

# %%
import trackio as tio

# %%
#define the data_path
data_path = './example0'

#read the processed Dataset
ds = tio.read(data_path=data_path)

ds
# Out:
# Type:
#     <class 'trackio.Dataset.Dataset'>
# Status:
#     0 Unprocessed CSV Files
#     0 Processed CSV Files
#     0 Unsplit Agent Files
#     172 Split Agent Files
# Static Data Fields:
#     ['AISCode', 'Agent ID', 'Length', 'MMSI', 'Name', 'Width']
# Dynamic Data Fields:
#     ['Coursing', 'Draft', 'Speed', 'Status', 'Time', 'X', 'Y']
# Metadata:
#     X: degrees
#     Y: degrees
#     CRS: EPSG:4326
# Data Path:
#     c:\code\trackio\notebooks\example0

# %% [markdown]
# ___
# ## Notice how the split agent (track) files are detected, along with the metadata, agent, and track databases

# %%
ds.agents.head(5)
# Out:
#                        MMSI          Name AISCode Length Width npoints  \
# Agent ID
# Vessel_367796040  367796040       SEA FOX    31.0   22.0   7.0    1134
# Vessel_366769330  366769330  PAULA ATWELL    31.0   27.0   8.0     455
# Vessel_338329000  338329000   KINGS POINT    31.0   29.0   NaN     709
# Vessel_366756360  366756360     SEA EAGLE    31.0   37.0  10.0      48
# Vessel_367022790  367022790      QUENAMES    31.0   22.0   7.0    1174
#
#                  ntracks      Xmin      Xmax      Ymin      Ymax  \
# Agent ID
# Vessel_367796040       1 -74.07762 -73.95417  40.66082  40.76055
# Vessel_366769330       1 -73.99933 -73.99814  40.58833  40.58905
# Vessel_338329000       1 -74.12816 -73.95416  40.64332  40.76064
# Vessel_366756360       1  -74.1246 -74.00965  40.64379  40.76064
# Vessel_367022790       1 -74.11035  -73.9552  40.64675  40.76022
#
#                           Start Time            End Time  \
# Agent ID
# Vessel_367796040 2021-01-01 00:17:16 2021-01-01 23:59:56
# Vessel_366769330 2021-01-01 00:19:36 2021-01-01 23:58:43
# Vessel_338329000 2021-01-01 00:17:16 2021-01-01 15:15:07
# Vessel_366756360 2021-01-01 01:12:38 2021-01-01 02:05:57
# Vessel_367022790 2021-01-01 00:17:15 2021-01-01 22:38:55
#
#                                                                File  \
# Agent ID
# Vessel_367796040  c:\code\trackio\notebooks\example0\Vessel_3677...
# Vessel_366769330  c:\code\trackio\notebooks\example0\Vessel_3667...
# Vessel_338329000  c:\code\trackio\notebooks\example0\Vessel_3383...
# Vessel_366756360  c:\code\trackio\notebooks\example0\Vessel_3667...
# Vessel_367022790  c:\code\trackio\notebooks\example0\Vessel_3670...
#
#                                                            geometry
# Agent ID
# Vessel_367796040  POLYGON ((-73.95417 40.66082, -73.95417 40.760...
# Vessel_366769330  POLYGON ((-73.99814 40.58833, -73.99814 40.589...
# Vessel_338329000  POLYGON ((-73.95416 40.64332, -73.95416 40.760...
# Vessel_366756360  POLYGON ((-74.00965 40.64379, -74.00965 40.760...
# Vessel_367022790  POLYGON ((-73.95520 40.64675, -73.95520 40.760...

# %%
ds.tracks.head(5)
# Out:
#                           MMSI          Name  AISCode  Length  Width  \
# Track ID
# Vessel_367796040_T0  367796040       SEA FOX     31.0    22.0    7.0
# Vessel_366769330_T0  366769330  PAULA ATWELL     31.0    27.0    8.0
# Vessel_338329000_T0  338329000   KINGS POINT     31.0    29.0    NaN
# Vessel_366756360_T0  366756360     SEA EAGLE     31.0    37.0   10.0
# Vessel_367022790_T0  367022790      QUENAMES     31.0    22.0    7.0
#
#                              Agent ID  npoints      Xmin      Xmax      Ymin  \
# Track ID
# Vessel_367796040_T0  Vessel_367796040     1134 -74.07762 -73.95417  40.66082
# Vessel_366769330_T0  Vessel_366769330      455 -73.99933 -73.99814  40.58833
# Vessel_338329000_T0  Vessel_338329000      709 -74.12816 -73.95416  40.64332
# Vessel_366756360_T0  Vessel_366756360       48 -74.12460 -74.00965  40.64379
# Vessel_367022790_T0  Vessel_367022790     1174 -74.11035 -73.95520  40.64675
#
#                      ...      Yend Effective Distance Min Temporal Resolution  \
# Track ID             ...
# Vessel_367796040_T0  ...  40.68622           0.000030                      10
# Vessel_366769330_T0  ...  40.58843           0.000679                      70
# Vessel_338329000_T0  ...  40.76064           0.152931                       9
# Vessel_366756360_T0  ...  40.64379           0.163913                      60
# Vessel_367022790_T0  ...  40.76022           0.190134                       9
#
#                     Mean Temporal Resolution  Max Temporal Resolution  \
# Track ID
# Vessel_367796040_T0                75.339806                     7989
# Vessel_366769330_T0               187.548458                      541
# Vessel_338329000_T0                76.088983                     5400
# Vessel_366756360_T0                68.063830                       71
# Vessel_367022790_T0                68.627451                       92
#
#                      Min Spatial Resolution  Mean Spatial Resolution  \
# Track ID
# Vessel_367796040_T0                0.000000                 0.000360
# Vessel_366769330_T0                0.000000                 0.000052
# Vessel_338329000_T0                0.000000                 0.000484
# Vessel_366756360_T0                0.003187                 0.003985
# Vessel_367022790_T0                0.000000                 0.000231
#
#                      Max Spatial Resolution     Sinuosity  \
# Track ID
# Vessel_367796040_T0                0.004348  13606.709065
# Vessel_366769330_T0                0.000691     34.660399
# Vessel_338329000_T0                0.004860      2.239005
# Vessel_366756360_T0                0.005055      1.142752
# Vessel_367022790_T0                0.002721      1.425217
#
#                                                               geometry
# Track ID
# Vessel_367796040_T0  POLYGON ((-73.95417 40.66082, -73.95417 40.760...
# Vessel_366769330_T0  POLYGON ((-73.99814 40.58833, -73.99814 40.589...
# Vessel_338329000_T0  POLYGON ((-73.95416 40.64332, -73.95416 40.760...
# Vessel_366756360_T0  POLYGON ((-74.00965 40.64379, -74.00965 40.760...
# Vessel_367022790_T0  POLYGON ((-73.95520 40.64675, -73.95520 40.760...
#
# [5 rows x 31 columns]

# %% [markdown]
# ___
# ## TODO You can also subset the original Dataset by simply passing a list of track files with the `data_files` keyword argument.
# ___
