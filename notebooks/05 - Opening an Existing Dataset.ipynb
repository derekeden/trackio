# %% [markdown]
# # Now you have your data ready to work with. You can now access this Dataset anytime without having to do any of the processing steps that were just completed.
#
# # Simply instantiate the Dataset by passing the `data_path` keyword argument, and it will detect the processed files.

# %%
import trackio as tio

# %%
#define the data_path
data_path = 'example0'

#read the processed Dataset
ds = tio.read(data_path=data_path)

ds
# Out:
# Type:
#     <class 'trackio.Dataset.Dataset'>
# Status:
#     0 Unprocessed CSV Files
#     0 Processed CSV Files
#     0 Unsplit Agent Files
#     172 Split Agent Files
# Static Data Fields:
#     ['AISCode', 'Agent ID', 'Length', 'MMSI', 'Name', 'Width']
# Dynamic Data Fields:
#     ['Coursing', 'Draft', 'Speed', 'Status', 'Time', 'X', 'Y']
# Metadata:
#     X: degrees
#     Y: degrees
#     CRS: EPSG:4326
# Data Path:
#     c:\code\trackio\notebooks\example0

# %% [markdown]
# # Notice how the split agent (track) files are detected, along with the metadata, agent, and track databases

# %%
ds.agents.head(5)
# Out:
#                        MMSI           Name AISCode Length Width npoints  \
# Agent ID
# Vessel_338073000  338073000      JRT MORAN    31.0   27.0   NaN      57
# Vessel_338380535  338380535        WING IT    36.0   16.0   5.0     401
# Vessel_367098070  367098070     GULF COAST    31.0   28.0   9.0     747
# Vessel_367563930  367563930  DEAN REINAUER    31.0   35.0  10.0     446
# Vessel_367069240  367069240   C F CAMPBELL    31.0   32.0   9.0     324
#
#                  ntracks      Xmin      Xmax      Ymin      Ymax  \
# Agent ID
# Vessel_338073000       1 -74.12648 -74.05474  40.62566  40.65105
# Vessel_338380535       1 -74.04486 -74.04475   40.7108  40.71095
# Vessel_367098070       1 -74.11835 -74.00149  40.63882  40.66594
# Vessel_367563930       1 -74.12826 -74.01036   40.5931  40.76108
# Vessel_367069240       1  -74.1227 -73.95377  40.63918  40.76081
#
#                           Start Time            End Time  \
# Agent ID
# Vessel_338073000 2021-01-01 00:17:18 2021-01-01 01:19:59
# Vessel_338380535 2021-01-01 00:18:44 2021-01-01 23:54:45
# Vessel_367098070 2021-01-01 00:17:12 2021-01-01 23:57:28
# Vessel_367563930 2021-01-01 03:02:25 2021-01-01 22:13:45
# Vessel_367069240 2021-01-01 00:19:43 2021-01-01 09:36:17
#
#                                                                File  \
# Agent ID
# Vessel_338073000  c:\code\trackio\notebooks\example0\Vessel_3380...
# Vessel_338380535  c:\code\trackio\notebooks\example0\Vessel_3383...
# Vessel_367098070  c:\code\trackio\notebooks\example0\Vessel_3670...
# Vessel_367563930  c:\code\trackio\notebooks\example0\Vessel_3675...
# Vessel_367069240  c:\code\trackio\notebooks\example0\Vessel_3670...
#
#                                                            geometry
# Agent ID
# Vessel_338073000  POLYGON ((-74.05474 40.62566, -74.05474 40.651...
# Vessel_338380535  POLYGON ((-74.04475 40.71080, -74.04475 40.710...
# Vessel_367098070  POLYGON ((-74.00149 40.63882, -74.00149 40.665...
# Vessel_367563930  POLYGON ((-74.01036 40.59310, -74.01036 40.761...
# Vessel_367069240  POLYGON ((-73.95377 40.63918, -73.95377 40.760...

# %%
ds.tracks.head(5)
# Out:
#                           MMSI           Name  AISCode  Length  Width  \
# Track ID
# Vessel_338073000_T0  338073000      JRT MORAN     31.0    27.0    NaN
# Vessel_338380535_T0  338380535        WING IT     36.0    16.0    5.0
# Vessel_367098070_T0  367098070     GULF COAST     31.0    28.0    9.0
# Vessel_367563930_T0  367563930  DEAN REINAUER     31.0    35.0   10.0
# Vessel_367069240_T0  367069240   C F CAMPBELL     31.0    32.0    9.0
#
#                              Agent ID  npoints      Xmin      Xmax      Ymin  \
# Track ID
# Vessel_338073000_T0  Vessel_338073000       57 -74.12648 -74.05474  40.62566
# Vessel_338380535_T0  Vessel_338380535      401 -74.04486 -74.04475  40.71080
# Vessel_367098070_T0  Vessel_367098070      747 -74.11835 -74.00149  40.63882
# Vessel_367563930_T0  Vessel_367563930      446 -74.12826 -74.01036  40.59310
# Vessel_367069240_T0  Vessel_367069240      324 -74.12270 -73.95377  40.63918
#
#                      ...      Xend      Yend Effective Distance  \
# Track ID             ...
# Vessel_338073000_T0  ... -74.12648  40.64320           0.069259
# Vessel_338380535_T0  ... -74.04483  40.71090           0.000030
# Vessel_367098070_T0  ... -74.11808  40.64191           0.000014
# Vessel_367563930_T0  ... -74.12791  40.64211           0.167248
# Vessel_367069240_T0  ... -73.95377  40.76081           0.204708
#
#                     Min Temporal Resolution  Mean Temporal Resolution  \
# Track ID
# Vessel_338073000_T0                      20                 67.160714
# Vessel_338380535_T0                     176                212.402500
# Vessel_367098070_T0                       9                114.230563
# Vessel_367563930_T0                      18                155.235955
# Vessel_367069240_T0                      12                103.386997
#
#                      Max Temporal Resolution  Min Spatial Resolution  \
# Track ID
# Vessel_338073000_T0                       72                0.000028
# Vessel_338380535_T0                      543                0.000000
# Vessel_367098070_T0                      361                0.000000
# Vessel_367563930_T0                    13271                0.000000
# Vessel_367069240_T0                      541                0.000000
#
#                      Mean Spatial Resolution  Max Spatial Resolution  \
# Track ID
# Vessel_338073000_T0                 0.001809                0.003619
# Vessel_338380535_T0                 0.000021                0.000100
# Vessel_367098070_T0                 0.000377                0.004672
# Vessel_367563930_T0                 0.000802                0.003849
# Vessel_367069240_T0                 0.000813                0.003210
#
#                                                               geometry
# Track ID
# Vessel_338073000_T0  POLYGON ((-74.05474 40.62566, -74.05474 40.651...
# Vessel_338380535_T0  POLYGON ((-74.04475 40.71080, -74.04475 40.710...
# Vessel_367098070_T0  POLYGON ((-74.00149 40.63882, -74.00149 40.665...
# Vessel_367563930_T0  POLYGON ((-74.01036 40.59310, -74.01036 40.761...
# Vessel_367069240_T0  POLYGON ((-73.95377 40.63918, -73.95377 40.760...
#
# [5 rows x 30 columns]

# %% [markdown]
# # You can also subset the original Dataset by simply passing a list of track files with the `data_files` keyword argument.
#
# # WILL ADD AFTER FIXING OUTPATH SHIT
